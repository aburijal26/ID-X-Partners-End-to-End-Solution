# %% [markdown]
# <a href="https://colab.research.google.com/github/aburijal26/ID-X-Partners-End-to-End-Solution/blob/main/ID_X_Partners_Intern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt

# %%
5.5*25
# Out:
# 137.5

# %%
aplication = pd.read_csv('application_record.csv')
credit = pd.read_csv('credit_record.csv')
df = pd.DataFrame(aplication)

# %%
print(df)
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 279250  6112353           F            N               N             0
# 279251  6112354           F            N               N             0
# 279252  6112358           M            Y               N             1
# 279253  6112359           M            Y               N             1
# 279254  6112360           M            Y               N             1
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
from ggplot import *
ggplot(mpg, aes(x = displ, y = hwy, hue = class)) + geom_point()
# Out:
#   File "<ipython-input-278-85917377ebbc>", line 2
#     ggplot(mpg, aes(x = displ, y = hwy, hue = class)) + geom_point()
#                                                   ^
# SyntaxError: invalid syntax

# %%
sns.displot(df['AGE'], bins=20)

# %%
print(df['AMT_INCOME_TOTAL'])
# Out:
# 0         427500.0
# 1         427500.0
# 2         112500.0
# 3         270000.0
# 4         270000.0
#             ...
# 438552    135000.0
# 438553    103500.0
# 438554     54000.0
# 438555     72000.0
# 438556    121500.0
# Name: AMT_INCOME_TOTAL, Length: 438557, dtype: float64

# %%
df[['CODE_GENDER']].head()
# Out:
#   CODE_GENDER
# 0           M
# 1           M
# 2           M
# 3           F
# 4           F

# %%
one_hot = pd.get_dummies(df['CODE_GENDER'],drop_first=True)
one_hot.head()
# Out:
#    M
# 0  1
# 1  1
# 2  1
# 3  0
# 4  0

# %%
df.drop(['ID', 'CODE_GENDER'], axis=1, inplace=False)
# Out:
#        FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0                 Y               Y             0          427500.0
# 1                 Y               Y             0          427500.0
# 2                 Y               Y             0          112500.0
# 3                 N               Y             0          270000.0
# 4                 N               Y             0          270000.0
# ...             ...             ...           ...               ...
# 438552            N               Y             0          135000.0
# 438553            N               N             0          103500.0
# 438554            N               N             0           54000.0
# 438555            N               Y             0           72000.0
# 438556            N               Y             0          121500.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                    Working               Higher education
# ...

# %%
df.drop(['ID', 'CODE_GENDER'], axis=1, inplace=True)

# %%
print(df[['ID']])
# Out:
#              ID
# 0       5008804
# 1       5008805
# 2       5008806
# 3       5008808
# 4       5008809
# ...         ...
# 438552  6840104
# 438553  6840222
# 438554  6841878
# 438555  6842765
# 438556  6842885
#
# [438557 rows x 1 columns]

# %%
type(df.ID.values[0])
# Out:
# numpy.int64

# %%
df.ID = df.ID.astype(str)
type(df.ID.values[0])
# Out:
# str

# %%
df['OCCUPATION_TYPE'].isnull().sum()
print(df['OCCUPATION_TYPE'])
# Out:
# 0                Unknown
# 1                Unknown
# 2         Security staff
# 3            Sales staff
# 4            Sales staff
#                ...
# 438552           Unknown
# 438553          Laborers
# 438554       Sales staff
# 438555           Unknown
# 438556       Sales staff
# Name: OCCUPATION_TYPE, Length: 438557, dtype: object

# %%
#df['OCCUPATION_TYPE'] = df['OCCUPATION_TYPE'].fillna('Unknown')
df['OCCUPATION_TYPE'].fillna('Unknown',inplace=True)

# %%
df['OCCUPATION_TYPE'].isnull().sum()
df['OCCUPATION_TYPE'].head()
print(df['OCCUPATION_TYPE'])
# Out:
# 0                Unknown
# 1                Unknown
# 2         Security staff
# 3            Sales staff
# 4            Sales staff
#                ...
# 438552           Unknown
# 438553          Laborers
# 438554       Sales staff
# 438555           Unknown
# 438556       Sales staff
# Name: OCCUPATION_TYPE, Length: 438557, dtype: object

# %%
df[['DAYS_BIRTH']].head()
# Out:
#    DAYS_BIRTH
# 0      -12005
# 1      -12005
# 2      -21474
# 3      -19110
# 4      -19110

# %%
df['AGE'] = df['DAYS_BIRTH'] / -365
df['AGE'] = df['AGE'].apply(np.floor)
df[['DAYS_BIRTH','AGE']].head()
# Out:
#    DAYS_BIRTH   AGE
# 0      -12005  32.0
# 1      -12005  32.0
# 2      -21474  58.0
# 3      -19110  52.0
# 4      -19110  52.0

# %%
sns.boxplot('AGE', data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df[['FLAG_PHONE']].head()
# Out:
#    FLAG_PHONE
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1

# %%
from tables.attributeset import np
df['FLAG_PHONE'] = np.where(df['FLAG_PHONE'] == 0,'Y','N')
df[['FLAG_PHONE']].head()
# Out:
#   FLAG_PHONE
# 0          Y
# 1          Y
# 2          Y
# 3          N
# 4          N

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['NAME_EDUCATION_TYPE_enc'] = label_encoder.fit(df['NAME_EDUCATION_TYPE'])
df[['NAME_EDUCATION_TYPE','NAME_EDUCATION_TYPE_enc']].head()
# Out:
#              NAME_EDUCATION_TYPE NAME_EDUCATION_TYPE_enc
# 0               Higher education          LabelEncoder()
# 1               Higher education          LabelEncoder()
# 2  Secondary / secondary special          LabelEncoder()
# 3  Secondary / secondary special          LabelEncoder()
# 4  Secondary / secondary special          LabelEncoder()

# %%
df = pd.DataFrame(aplication)
df.info()
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
df = df.drop(columns = 'CODE_GENDER')
df.head()
# Out:
#         ID FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0  5008804            Y               Y             0          427500.0
# 1  5008805            Y               Y             0          427500.0
# 2  5008806            Y               Y             0          112500.0
# 3  5008808            N               Y             0          270000.0
# 4  5008809            N               Y             0          270000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
# ...

# %%
aplication.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152425 entries, 0 to 152424
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   152425 non-null  int64
#  1   CODE_GENDER          152424 non-null  object
#  2   FLAG_OWN_CAR         152424 non-null  object
#  3   FLAG_OWN_REALTY      152424 non-null  object
#  4   CNT_CHILDREN         152424 non-null  float64
#  5   AMT_INCOME_TOTAL     152424 non-null  float64
#  6   NAME_INCOME_TYPE     152424 non-null  object
#  7   NAME_EDUCATION_TYPE  152424 non-null  object
#  8   NAME_FAMILY_STATUS   152424 non-null  object
#  9   NAME_HOUSING_TYPE    152424 non-null  object
#  10  DAYS_BIRTH           152424 non-null  float64
#  11  DAYS_EMPLOYED        152424 non-null  float64
#  12  FLAG_MOBIL           152424 non-null  float64
#  13  FLAG_WORK_PHONE      152424 non-null  float64
# ...

# %%
aplication.describe().T
# Out:
#                      count          mean            std      min        25%  \
# ID                152425.0  5.473446e+06  403064.492320      5.0  5159251.0
# CNT_CHILDREN      152424.0  4.341639e-01       0.736127      0.0        0.0
# AMT_INCOME_TOTAL  152424.0  1.856388e+05  105660.675825  27000.0   117000.0
# DAYS_BIRTH        152424.0 -1.603067e+04    4201.362958 -25201.0   -19529.0
# DAYS_EMPLOYED     152424.0  6.243917e+04  140351.191808 -17531.0    -3054.0
# FLAG_MOBIL        152424.0  1.000000e+00       0.000000      1.0        1.0
# FLAG_WORK_PHONE   152424.0  2.159306e-01       0.411468      0.0        0.0
# FLAG_PHONE        152424.0  2.995919e-01       0.458081      0.0        0.0
# FLAG_EMAIL        152424.0  8.519000e-02       0.279165      0.0        0.0
# CNT_FAM_MEMBERS   152424.0  2.205283e+00       0.907687      1.0        2.0
#
#                         50%        75%        max
# ID                5401550.0  5632424.0  6840318.0
# ...

# %%
print(aplication.shape)
print(aplication.ID.nunique())
# Out:
# (152425, 18)
# 152425

# %%
credit.sample()
# Out:
#              ID  MONTHS_BALANCE STATUS
# 853943  5118479             -20      0
